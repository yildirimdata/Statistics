# %% [markdown]
# # DATA TYPES, PATTERNS AND GRAPHS
#
# **What is Statistics?**
#
# A well  written and explanatory reading for data types and level of measurement (scale) : https://careerfoundry.com/en/blog/data-analytics/data-levels-of-measurement/
#
# An online tutorial : https://www.youtube.com/watch?v=sxQaBpKfDRk&list=PL8dPuuaLjXtNM_Y-bUAhblSAdWRnmBUcr&index=2
#
# **Terms**
#
# Numerical information
#
# Decision making
#
# Descriptive statistics
#
# Inferential statistics
#
# Exploratory data analysis(EDA) : keşfedici/açınsayıcı veri analizi
#
# Discrete data: ayrık veri, kesikli veri
#
# Numerical Data X Categorical data
#
# ND: Discrete data(kesikli) and Continuous(sürekli) data
#
# CD: Nominal data and Ordinal data
#
# Statistics is playing an increasingly important part of many processes of **decision making** today. The relationship between data and statistics is very strong because data in the real world can be processed by statistics and meaningful trends can be obtained from it by performing mathematical calculations within the framework of statistics.
#
# **Definiton**: Statistics is the discipline that concerns the collection, organization, analysis, interpretation and presentation of data.
#
# **Two basic divisions of statistics are descriptive and inferential statistics**:
#
# **Descriptive statistics** are numbers that are used to **summarize and describe data**.
#
# **Inferential(çıkarımsal-tahminsel) statistics** is a way of making inferences about populations based on samples.
#
# Descriptive statistics describes data in some manner (a graph or numerical summary) and inferential statistics allows you to make predictions based on samples.

# %% [markdown]
# ![image.png](attachment:6c5f38e0-97ea-4a11-8c3a-f7b68e60e38a.png)

# %% [markdown]
# **TYPES of DATA**
#
# **Data** are characteristics or information, usually numerical, that are collected through observation.
#
# Veriler ölçüm, sayım, deney, gözlem ya da araştırma yolu ile elde edilmektedir. Ölçüm ya da sayım yolu ile toplanan ve sayısal bir değer bildiren veriler nicel veriler, sayısal bir değer bildirmeyen veriler de nitel veriler olarak adlandırılmaktadır.
#
# **There are two main types of data types**: numerical (or quantitative) data and categorical (or qualitative) data.
# Categorical data refers to a data type that can be stored and identified based on the names or labels given to them. Numerical data refers to the data that is in the form of numbers, and not in any language or descriptive form.
#
# **1) Numerical Data**
#
# Numerical data includes counts or measurements. It can be further classified into discrete and continuous data.
#
# **Discrete data contains only finite values.** For example the number of students in a school, the number of buildings in a city, the number of desks in a classroom, etc. A possible number of students in a school cannot be infinite. It can be 300, 301 or 302, but it cannot be something between 300 and 301. You can somehow count the values it can take.
#
# **Continuous data** can have an infinite number of values between any two values. For example age, height or weight of a person, the time assigned to a special task, house price, stock price, etc. A stock price might be 10, 11 or 10.4565 dollars, so it can have an infinite number of values. The age of a person is a continuous data because your exact age might be 28, 28.1 or 28.5.
#
# **Continuous variables are sometimes divided into interval variables and ratio variables.** In an interval variable the distance between readings is interpreted the same no matter where you are on the continuum. For example, the distance between 3kg and 5kg, is the same as the distance between 7kg and 9kg. Ratio variables are interval variables where zero means the absence of something. For example, height is a ratio variable. On the other hand, temperature in degrees centigrade is not a ratio variable, since zero degrees does not mean the absence of temperature.
#
# A numerical variable is discrete if its possible values form a set of separate numbers, such as 0, 1, 2, 3, ...
# A numerical variable is continuous if its possible values form an interval.
#
# **2) Categorical Data**
#
# Categorical data can only take a specific set of values representing a set of possible categories, such as female/male genders, automatic/semi-automatic or manual gearboxes. We can assign numbers to categorical data, for example, we can use 0 for male and 1 for female. But even in this case, numbers do not have actual numerical meaning. They represent the categories.
#
# **Categorical data can be further classified into nominal and ordinal data.** **Nominal data** simply names something **without an order** being given. Female/male genders, automatic/semi-automatic or manual gearboxes are examples for nominal data. Dinler mesela. ISlam, Christianity, Judaism.. İnsanlar sınıflandırılabilir ama sınıfların birbirine üstünlüğü yok.
#
# **Nominal veriler** kategorik bir veri çeşidiri. **"Daha fazla"** ifadesi ile kullanılmazlar. **Ordinal veriler**, değerleri arasında sıralı bir ilişki bulunan kategorik verilerdir. **"Daha fazla"** ifadesi ile kullanılabilirler, ancak ne kadar daha fazla olduğunun ölçüsünü veremezler. İkiye ayrılır:
#
# a)  Dichotomous(dikotom) Veriler : Var-Yok, Kadın-Erkek, Hasta-Sağlıklı, death-alive
#
# b)  İkiden Çok Kategorili : Medeni Durum-Renk-Irk-Şehir, İsim, Forma Numarası.Örneğin forma numarası oyuncunun seviyesi ile ilgili bir bilgi içermez.
#
# Nominal variables (from Latin for name) are things like eye colour or hair colour. We might have: 1=blue eyes, 2=brown eyes, 3=green eyes. However, we might equally have: 1=brown eyes, 2=green eyes, 3=blue eyes. In other words, is the label that is important, not the number attached to it. When we describe nominal variables or dichotomous variables, we simply count the number and percentage in each category. It would make no sense to for example, ask what the average eye colour is!
#
# Unlike nominal data, **ordinal data requires an order**. For example, suppose you had dinner in a restaurant and they asked if you could participate in the survey. You might rank the taste of the meal as "1" for bad, "2" for average and "3" for good. The survey data is a good example of ordinal data. Here we use numbers for categorical data but as we mentioned above, they do not have actual numerical meaning. Another example can be given about body sizes for a shirt. Small, Medium, Large sizes all represent the ordinal data. Because there is an order between these categories. Educational level for ex: elementary, secondary, ba, ma , phd...
#
# Nominal veriler, ordinal verilere daha az bilgi taşırlar.
#
# An ordinal data is a categorical one for which the categories are ordered from low to high in some sense.
# A nominal data is a categorical data that do not have a natural order or ranking.
#
# ![image.png](attachment:b9899809-0761-4f9b-8114-cc951292ca5b.png)
#
# Turkish source for basic data types: https://mervetatlidil.medium.com/veri-türleri-ve-i̇statistiğe-giriş-2959f509f768
#
# ![image.png](attachment:962bbd2c-0a61-4c6d-8a43-155612cc8c9b.png)

# %% [markdown]
# **Interval (aralıklı) veriler:**
#
# - Nesnelerin sıralanmasında kullanılır.
#
# - Eşit aralıkların eşit mesafelerini temsil ettiği bir ölçek türüdür.
#
# - Ordinal ölçümün bütün özelliklerini taşır.
#
# - Nesneler arasındaki farkın mukayesesine imkan tanır.
#
# - Başlangıç noktası sorunu vardır. Araştırmacı kendi yaptığı çalışmaya göre bir başlangıç noktası belirler. (arbitrary zero)
#
# - Sıfır noktası sabit olmadığı için başlangıç noktası görecelidir.
#
# (Örnek: Küçük ve büyük tansiyonların değer aralıkları, Kan pH’ı 7.1 ile 7.5 arasında olması, vücut sıcaklığını ölçmek için kullanılan termometreler, likert ölçeği (tutum ve davranışları ölçmek için 1 ile 5 arasında değer vermek gibi, ya da kötü—harika tarzı anlamsal dizilimler..)
#
# **Ratio (Oransal) Veriler:**
#
# - Interval, ordinal ve nominal ölçüm türünün özelliklerini taşır.
#
# - Aynı zamanda mutlak sıfır noktasına da sahiptir. (absolute zero)
#
# - En üst ölçüm tekniğidir, her türlü istatiksel ve matematik işleme imkan tanımaktadır.
#
# - Cevaplayıcı sıfırdan herhangi bir sayıya kadar cevap verebilir.
#
# - Oransallık söz konusudur.
#
# (Örnek: Yıllık kazancınız ne kadar, kaç çocuğunuz var, sağlık alanında ağırlık ölçümü, boy ölçümü, fizik bilimindeki ölçümler ağırlık, alan, hacim gibi, ölen hastalanan yaralanan hakkındaki veriler vb.)

# %% [markdown]
# # DATA PATTERNS in STATISTICS
#
# **GRAPHICAL REPRESENTATION of DATA**
#
# Graphical representations are useful for viewing patterns in data. In general, we can define the patterns in data as follows: center, spread, shape, and unusual features.
#
# Some known distributions have some special descriptive labels such as symmetric, bell-shaped, skewed, etc.
#
# **a) Center**
#
# The center of a distribution, graphically, is located at the median of the distribution. Such a graphic chart displays that almost half of the observations are on either side. Height of each column indicates the frequency of observations.
#
# ![image.png](attachment:58b2b64b-fd37-4c26-85c3-9bb40aafe6f8.png)
#
# **b) Spread**
#
# The spread of a distribution is related to **the variation of the data**. If the set of observations spreads over a wide range, the spread is greater. If the observations are centered around a single value in a narrower range, then the spread is smaller.
#
# ![image.png](attachment:178077cd-7d6e-4ed8-bd39-512af49ec15b.png)
#
# **Variance and standard deviation are the most common statistics of variability.**
#
# **c) Shape**
#
# The shape of a distribution can described using following characteristics.
#
# **c.1) Symmetry:**
#
# In symmetric distribution, graph can be divided at the center in such a way that each half is a mirror image of the other. In the Normal Distribution, the two sides of the distribution are equal and symmetrical.
#
# ![image.png](attachment:fbe5b2c9-9509-4df0-a7a5-e8d107e8bd32.png)
#
# **c.2) Number of Peaks:**
#
# Distributions with one or multiple peaks. **Distribution with one clear peak is known as unimodal, and distribution with two clear peaks is called bimodal.** A single peak symmetric distribution at the center, is referred to as bell-shaped.
#
# ![image.png](attachment:bf93dc91-e865-4990-9cfd-adea37a60ecb.png)
#
# **c.3) Skewness (Eğrilik, asimetri)**
#
# Some distributions may have multiple observations on one side of the graph than the other side. Distributions having fewer observations towards higher values are said to be skewed right; and distributions with fewer observations towards lower values are said to be skewed left.
#
# ![image.png](attachment:dcf98167-4474-4b1e-9f8e-6d9f4d8625c2.png)
#
# **Positive Skewness** means when the tail on the right side of the distribution is longer or fatter. The mean and median will be greater than the mode. Genrally the mean is larger than the median.
#
# **Negative Skewness** is when the tail of the left side of the distribution is longer or fatter than the tail on the right side. The mean and median will be less than the mode.
#
# ![image.png](attachment:cfa026f6-0146-4623-8cc7-f5b01aa5573d.png)
#
# Additional reading for skew: https://codeburst.io/2-important-statistics-terms-you-need-to-know-in-data-science-skewness-and-kurtosis-388fef94eeaa
#
# Kurtosis(basıklık) da skewnessla ilişkili. Eğer normale göre bir eğri daha sivri ise kurtosis katsayısı yüksek, dağa basık ise kurtosis katsayısı daha küçüktür. Kurtosis katsayısı SD ile ters orantılıdır.
#
# **c.4) Uniform:**
#
# When the set of observations has no peak and have data equally spread across the range of the distribution, then the distribution is called a uniform distribution.
#
# ![image.png](attachment:93d1e552-4602-4a9a-9c2f-8863299e7f4b.png)
#
# **d) Unusual Features:**
#
# **Common unusual features of data patterns are gaps and outliers.**
#
# **d.1) Gaps:**
#
# Gaps points to areas of a distribution having no observations. Following figure has a gap as there are no observations in the middle of the distribution.
#
# ![image.png](attachment:daab9a7e-c1c4-4253-9488-ab140da5186b.png)
#
# **d.2) Outliers:**
#
# Distributions may be characterized by extreme values that differ greatly from the other set of observation data. These extreme values are refered as outliers. Following figure illustrates a distribution with an outlier.
#
# ![image.png](attachment:72d93c4e-028e-40de-ad1f-2890f4c277c0.png)

# %% [markdown]
# TASK: Randomly generate 1,000 samples from the normal distribution using np.random.normal()(mean = 100, standard deviation = 15)
#
# np.random.normal(loc=0.0, scale=1.0, size=None) #you need to modify this code.
#
# loc will be equal to mean, scale will be equal to std deviation, size will be equal to sample size.

# %%
import scipy
import numpy as np
from scipy import stats


samples = np.random.normal(loc=100, scale=15, size=1000)

# Compute the skewness and kurtosis
# We can use scipy.stats.skew and scipy.stats.kurtosis

skewness = scipy.stats.skew(samples)
kurtosis = scipy.stats.kurtosis(samples)
print(skewness, kurtosis, sep="\n")
# Out:
# -0.1489478592389624
# -0.14128859487727308

# %% [markdown]
# **FREQUENCY TABLE**
#
# A frequency table is a table that lists items and shows the number of times the items occur. It is a listing of possible values for a variable, together with the number of observations for each value. **The relative frequency of a category or a numerical value is the associated frequency divided by the total number of data.** The table below shows the frequencies of the various response categories. It also shows the relative frequencies, which are the proportion of responses in each category. For example, the relative frequency for "Front-end Developer" is 25/100 = 0.25.
#
# ![image.png](attachment:42c67e37-ddbe-4dcb-bea9-768c4c7fee57.png)
#
# ![image.png](attachment:61435653-79f1-4d66-9c31-33af2279f9d3.png)

# %% [markdown]
# # **We often use Pie Chart and Bar Chart to display the categorical data; and we often use histogram, stemplots and timeplots to display the quantitative data.**

# %% [markdown]
# **PIE CHART**
#
# A pie chart is a circle having a “slice of the pie” for each category. In a pie chart, each category is represented by a slice of the pie. The area of the slice is proportional to the percentage of responses in the category. This is simply the relative frequency multiplied by 100.
#
# ![image.png](attachment:4d492bdb-09d4-4e60-8617-1c33fc357ee0.png)
#
# Pie charts are effective for displaying the relative frequencies of a small number of categories. They are not recommended, however, when you have a large number of categories.
#
# Pie chart'ta her bir slice icin merkez açıyı da bilebiliriz. örneğin 50 öğrencilik sınıfta 45 kişi geçmisse geçenlerin slice'nın merkez açısı nedir? Bu dilimin relevant frequency'si %90. Yani 0.9. Bunu 360 ile çarparsak (pie'ın iç açı toplamı 360) merkez açısını buluruz. 324 drece. Relevant frequency'yi bulmak içinse o gruptakileri toplama bölüyoruz. Örneğin 60 kişiden 15 geçtiyse o slice'ın relevant frequency'si 4'te 1 yani %25'tir.

# %% [markdown]
# **BAR CHART**
#
# A bar chart is a chart that presents categorical data with rectangular (dikdörtgensel) bars with heights proportional to the values that they represent. Bar charts can be used to represent frequencies of different categories. A bar chart is made up of columns plotted on (plot on: üzerine çizmek "plot on x axis")) a graph.
#
# A bar chart of the developers employed in a company is shown below. **Frequencies are shown on the Y-axis and the type of developers is shown on the X-axis.** Typically, the Y-axis shows the number of observations in each category rather than the percentage of observations as is typical in pie charts.
#
# **Önemli: Kategorileri x eksenine, frekansı (o kategoriye ait değeri) y eksenine koyarız.**
#
# ![image.png](attachment:3f67b43f-ea6b-442c-8d09-1ddb5d33f8bd.png)
#
# **The bars can be plotted vertically or horizontally.** Kategoriler çok fazla ise ve x ekseninde karisik duruyorsa y ekseninde de verilebilir, horizontal bar chart da olabilir yani. A vertical bar chart is sometimes called a **column chart**.

# %% [markdown]
# **HISTOGRAM**
#
# Terms: class interval, upper limit of CI and lower limit of CI, class frquency, grouped data, bin width, frequency poligon...
#
# Sütunlu diagram. Diagram çizge. **Gruplandırılmış serilerde kullanılır**. It's a frequency distribution. We can display the data showed in a histogramm as a frequency table too.
#
# A histogram is a graphical representation of a distribution. It's used with numerical variables. It is a graphical method for displaying the shape of a distribution. It is particularly useful when there are a large number of observations. We begin with an example consisting of the scores of 250 students on a statistics test. The students' scores ranged from 32 to 96.
#
# The first step is to create a **frequency table**. Unfortunately, a simple frequency table would be too big, containing over 100 rows. To simplify the table, we group scores together. To create this table, the range of scores was broken into **intervals, called class intervals**. The first interval is from 32 to 38.4, the second from 38.4 to 44.8, etc. Next, the number of scores falling into each interval was **counted to obtain the class frequencies**. There are one score in the first interval, 4 in the second, etc. **The widths of the class intervals, sometimes called bin widths (bin: çizgi grafiğinde kesikli aralıklar)**. Your choice of bin width determines the number of class intervals.
#
# ![image.png](attachment:218bf014-ee27-4362-9445-143cd4201580.png)
#
# In a histogram, the class frequencies are represented by bars. The height of each bar corresponds to its class frequency. A histogram of these data is shown below.
#
# Bu histogramda gerçek frekansları kullandık. Bir diğer gösterim yöntemi de ayarlanmış frekanslardır. (fi') Ayarlanmış frekansları bulmak için frekansı class interval'a böleriz. örneğin 32-38.4 puan aralığındaki öğrenci sayısı 10 ise, 10'u 6.4'e böler ve ayarlanmış frekans aralığına ulaşırız. fi' y, class intervals x axiste gösterilir normal.
#
# ![image.png](attachment:d5fc32bf-dad3-4caa-a3a6-1630b34b2ae2.png)
#
# The histogram makes it plain that most of the scores are in the middle of the distribution, with fewer scores in the extremes. We can see from the chart that frequency is greatest in the 64 to 70.4 score group.
#
# **With bar charts, the labels on the X axis are categorical (or discrete); with histograms, the labels are numerical (quantitative).** Bar chartta columnlar ayrı, histogramda bitisik durur.
#
# Histogramlar veya frequency tablelar genelde 1-20; 20-40; 40-60 vb gider. Burada bir soru; örneğin bir değer 20 ise 1-20ye mi yoksa 20-40a ı alınmalı? Geleneksel olarak br intervalın son değeri (20, 40,60) o sınıfa dahil değildir. Doalyısıyla bu örnekte 20-40',a girer. ikinci bir soru, neden o zaman 1-19,20-39... göstermiyoruz. Çünkü bu durumda örneğin 19.7, 39.5, 59.9 vb veriler histogram veya table'da kendine yer bulamaz.
#
# Histogram oluşturduktan sonra her dikdörtgenin üst orta noktalarının birleştirilmesiyle elde edilen eğriye frequency poligon (frekans poligonu) denir.

# %% [markdown]
# # **POPULATION and SAMPLE**
#
# **Population**
#
# Population means the aggregation of all the elements under study with one or more common features. It's not limited with the people. It is the total group about which you want to make conclusions.
#
# It can be of any size, and the number of elements or members in a population is known as population size. If there are a hundred million people in a country, then the population size is 100 million. Or population size of a car garage with 40 cars is 40.
#
# **Sample**
#
# A sample is a subset of the population for whom you actually have data. While conducting a statistical study, samples are mainly used when the population size is too large to include all the members of the population. For example, it is easier to conduct a study with 2000 people selected from 100 million people, rather than conducting a study involving 100 million people. The selected respondents from the population constitute a sample and **the selection process is known as sampling**. The elements under study are called **sampling units** (sample points, observations), and the number of units in a sample is called a **sample size**. We observe samples but are interested in populations.
#
# **Population Parameters and Sample Statistics**
#
# Of the numerical summaries introduced so far, the **mean x̄** (üstü çizgili x: artimetik ort sembolu) and the **standard deviation s** are the most commonly used in practice. **The formulas that define x̄ and s refer to sample data. They are sample statistics.**
#
# We will distinguish between sample statistics and the corresponding parameter values for the population. The population mean is the average of all observations in the population. The population standard deviation describes the variability of the population observations about the population mean. These are usually unknown. Inferential statistical methods help us to make decisions and predictions about the population parameters based on the sample statistics.
#
# **A parameter is a numerical summary of the population, and a statistic is a numerical summary of a sample.** Population attributes are called parameters and sample attributes are called statistics.
#
# İstatistik örnek verilere dayanır, popülasyon verilerine değil. Eğer verimizi tüm populasyondan toplamışsak, bu toplama işlemine sayım denir. Eğer biz bu sayımı sayıyla bir değişken üzerinden özetliyorsak , bu sayı istatistik değil parametre olur. Örn genel nüfus sayımı bir parametre, nüfusun belli bir grubunda yapılan refah anlet çalışması sonuçları istatistiktir.
#
# Bir üni için arş yapıyorsak tğm öğrencilerin yaş ort.sı parameter, 200 kişilik samplemızın yaş ort.sı ise istatistik olur. Parametreye ulaşmak imkansız/maliyetli olduğu icin ististikle parametreler tahmin edilmeye, infrences yapılmaya çalışılır. Mesela µ parametre, mean x ise istatistiktir.

# %% [markdown]
# # **SAMPLING TECHNIQUES**
#
# **Types of Sampling Methods**
#
# To draw valid conclusions from our results, we have to carefully decide how we will select a sample that is representative of the group as a whole. There are two types of sampling methods:
#
# **1) Probability Sampling (olasılıklı/tesadüfi örneklem-e-):** This involves random selection, allowing us to make strong statistical inferences about the whole group. This sampling method can also prevent selection bias.
#
# **2) Non-probability Sampling (tesadüfi olmayan örneklem-e-):** This involves non-random selection based on convenience or other criteria, allowing us to easily collect data.
#
# **1) Probability Sampling Methods**
#
# Probability sampling means that every member of the population has a chance of being selected.
#
# **1.1 Simple Random Sample:** In a simple random sample, every member of the population has an equal chance of being selected.
#
# **1.2 Systematic Sample:** Every member of the population is listed with a number, but instead of randomly generating numbers, individuals are chosen at regular intervals.
#
# **1.3 Stratified Sample(katmanlı/tabakalı örnekleme):** Stratified sampling involves dividing the population into subpopulations that may differ in important ways. Mesela kadınlar erkekler diye ikikye bölüp, ikisinden de random seçiliyor. Cinsiyet önemli ise erkek kadının toplama oranlarını dikkate alıp ona göre erkek veya kadın sayısı belirlenir. Yani stratified altında simple random sample (srs) yapmış oluruz.
#
# **1.4 Cluster Sample:** Cluster sampling involves dividing the population into subgroups, but each subgroup should have similar characteristics to the whole sample.
#
# ![image.png](attachment:4ee7440d-b715-48bc-a3eb-488bed7af25f.png)
#
# **2) Non-probability Sampling Methods**
#
# In a non-probability sample, individuals are selected based on non-random criteria, and not every individual has a chance of being included.
#
# **2.1 Convenience sample (kolay ulaşılabilr örnekleme-uygun örnekleme):** A convenience sample includes the observations who are most accessible to the researcher.
#
# **2.2 Voluntary response sample:** Similar to the convenience sample, the voluntary response sample is basically based on ease of access. Instead of the researcher selecting participants and communicating directly with them, participants volunteer themselves.
#
# **2.3 Purposive sample (amaçlı örnek):** This sampling method involves the researcher using their expertise to select the sample that best suits their research purpose.
#
# **2.4 Snowball sample (kartopu örneklemesi):** If the population is difficult to access, snowball sampling can be used to recruit participants through other participants.

# %% [markdown]
# ![image.png](attachment:a9147f81-ee84-4f2a-8f4f-4fcba4d70a54.png)
