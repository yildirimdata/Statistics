# %% [markdown]
# # Normal Distribution
#
# Complementary source: https://www.youtube.com/watch?v=mtbJbDwqWLE&t=515s
#
# **Normal (Gaussian) Distribution**
#
# **The normal distribution, also called the gaussian or bell curve, is a naturally occurring distribution** in most cases. The normal distribution can be seen in tests like the GRE or SAT. Most students will get an average score (C), while fewer students will receive a B or D. An even smaller number of students score an F or an A. That generates a distribution that resembles a bell that is why the normal distribution is also called the bell curve. The form of the normal distribution is symmetrical. Half of the data will fall to the right of the mean and the other half will fall to the left. Most of the data follow this type of pattern. The normal distribution is therefore commonly used in industry, statistics and public bodies.
#
# For example; Weights of people, Blood pressures, Scores on a test, IQ scores, Wages follow the normal distribution pattern.

# %% [markdown]
# **Properties of a Normal Distributions**
#
# The normal distribution has some principal characteristics:
#
# - Normal distributions are symmetric around their mean.
#
# - The mean, median, and mode of a normal distribution are equal.
#
# - The total area under the normal curve is equal to 1.0.
#
# - Normal distributions are described by two parameters, the mean (μ) and the standard deviation (σ). The mean determines its position. The std determines its spread. Larger std means more spreaded ND, smaller std means less spreaded ND.
#
# - It's unimodal. That means it has a singular peak.
#
# **NOTE: Don't forget that as std we address std for population (σ), and as mean the mean for population (μ).**
#
# **Tip:**
#
# Parameter is a number that describes the data from a population.
#
# Statistic is a number that describes the data from a sample.
#
# ![image.png](attachment:27d7bddf-bfc3-4d59-92c7-3ff6bfbbfcbc.png)

# %% [markdown]
# # The Area under the normal distribution curve
#
# ![image.png](attachment:763f20b2-bf12-44f2-a694-7c8390c06b25.png)
#
# Note: x eksenindeki valuelar std. (0,5 std)
#
# The total area under the normal curve is equal to 1.0. By using the two parameters(STD, mean) we can split the area under the normal distribution curve. In other words, the area under the normal distribution curve tells us what percentage of the data falls within a certain number of standard deviations from the mean:
#
# # **68-95-99,7 Rule** (The Empirical Rule)
#
# Approximately 68% of the area of a normal distribution is within one standard deviation of the mean,
#
# Approximately 95% of the area of a normal distribution is within two standard deviations of the mean,
#
# Approximately 99,7% of the area of a normal distribution is within three standard deviations of the mean.

# %% [markdown]
# ![image.png](attachment:1c32365c-7dfc-48cb-883c-e1cfaa973869.png)

# %% [markdown]
# # Z-Score
#
# Complementary source: https://www.youtube.com/watch?v=2tuBREK_mgE&feature=emb_imp_woyt
#
# Z değeri - standart sapma birimleri cinsinden bir mesafe ölçüsü.
#
# Standard normal distribution is a distribution with 0 mean and 1 std. Z-Score shows us how we are far from mean. For example on such a x axis (-3,-2,-1,0,1,2,3), if we are on 2 this means we are 2 std.s to the right of the mean (above the mean), or -1.5 means -1.5 std.s to the left of the mean (below the mean). Using z-score table (standart normal table), we can find the area this z-score corresponds to.
#
# If the mena and std are different from the mean 0 and std 1, we can have a **standardization** operation by using the z = (x(observation) - µ) / std formula. This gives us the z-score and enables us to calculate the area of the related part.
#
# We calculate the probability of an outcome by determining the area under the normal distribution curve. However, sometimes we need to find the probability of an outcome that does not fall directly within 1, 2, or even 3 standard deviations from the mean.
#
# We use the z score to standardize the normal distribution curve. Instead of mean in the normal distribution curve we insert the zero. Similar to the standard deviations to the left and right of the mean, we insert 1,2,3 and -1,-2,-3 to the left and right of the zero. The z scores represent the standard score. Therefore, a z-score of 1, is one standard deviation above the mean, and a z-score of -1, is one standard deviation below the mean.
#
# Rather than creating a normal distribution curve for each dataset, we can use one standard normal distribution curve by z-score and use the formulas to find probabilities.
#
# The basic z score formula for a z-score is:
#
# ![image.png](attachment:6a65c28f-4c4d-4515-bde3-89508c9667e4.png)
#
# **The z score tells you how many standard deviations from the mean your score is.** In this example, your score is 1,25 standard deviations above the mean.
#
# **Summary:** The z-score is a score that measures how many standard deviations a data point is away from the mean. **The z-score allows us to determine how usual or unusual a data point is in a distribution.** The z-score allows us more easily compare datapoints for a record across features, especially when the different features have significantly different ranges.

# %% [markdown]
# # Z Table
#
# **The z-table helps us to make a probability calculation by the z-score.** The table provides us with accurate proportion values for all z scores within -3.9 and +3.9 standard deviations from the mean. Therefore, we can find the probability for any dataset that is normally distributed by using the z-sore in the z-table.
#
# When using a z table, you should keep in mind that the values provided in the table represent the probability at or below the indicated z score. **Therefore, if you wish to find the probability of an outcome occurring after, or to the right, of the z-score you will need to use the fact that the total area under the normal curve is equal to 1.0 and subtract to find the desired probability.**
#
# We calculated the z-score as 1,25 for the previous example. By using this value in the z-table we can find the probability of getting a score of 205 or less. The z score tells you how many standard deviations from the mean your score is. In this example, your score is 1,25 standard deviations above the mean. (1.2+0.05=1.25)

# %% [markdown]
# We divide the z-score into two parts as 1,2 and 0,05 (1,2+0,05=1,25). We use the value of 1,2 on the left side of the table, and use the value of 0,05 on the top of the table. So we reach the probability of 0,8944 at the intersection point. That value means, % 89,44 of the students receive a score of 205 or less, where the test has a mean (μ) of 180 and a standard deviation (σ) of 20. Because the total area under the normal curve is equal to 1, we can say also that the probability of getting a score of greater than 205 is % 10,56.
#
# for z-table = https://www.z-table.com

# %%
# how to calculate z score from scratch traditionally with a for loop in list comp for the abovementioned example
values = [205]  # it must be iterable
mean = 180
standard_deviation = 20
zscores = [((value - mean) / standard_deviation) for value in values]
print(zscores)
# Out:
# [1.25]

# %% [markdown]
# # Calculating z-score with scipy.stats’ zscore()
#
# Source: https://datagy.io/python-z-score/
#
# scipy.stats.zscore(arr, axis=0, ddof=0) function computes the relative Z-score of the input data, relative to the sample mean and standard deviation.
#
# Parameters :
#
# arr : [array_like] Input array or object for which Z-score is to be calculated.
#
# axis : Axis along which the mean is to be computed. By default axis = 0.
#
# ddof : Degree of freedom correction for Standard Deviation.
#
# Results : Z-score of the input data.

# %%
# Calculate the z-score from with scipy
import scipy.stats as stats
values = [4,5,6,6,6,7,8,12,13,13,14,18]

zscores = stats.zscore(values)
print(zscores)
# Out:
# [-1.2493901  -1.01512945 -0.78086881 -0.78086881 -0.78086881 -0.54660817
#  -0.31234752  0.62469505  0.85895569  0.85895569  1.09321633  2.0302589 ]

# %% [markdown]
# # How to Use Pandas to Calculate a Z-Score
#
# There may be many times when you want to calculate the z-scores for a Pandas Dataframe. In this section, you’ll learn how to calculate the z-score for a Pandas column as well as for an entire dataframe. In order to do this, we’ll be using the scipy library to accomplish this.
#
# First we should load a sample Pandas Dataframe to calculate our z-scores:

# %%
# Loading a Sample Pandas Dataframe
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
import pandas as pd

df = pd.DataFrame.from_dict({
    'Name': ['Nik', 'Kate', 'Joe', 'Mitch', 'Alana'],
    'Age': [32, 30, 67, 34, 20],
    'Income': [80000, 90000, 45000, 23000, 12000],
    'Education' : [5, 7, 3, 4, 4]
})

print(df.head())
# Out:
#     Name  Age  Income  Education
# 0    Nik   32   80000          5
# 1   Kate   30   90000          7
# 2    Joe   67   45000          3
# 3  Mitch   34   23000          4
# 4  Alana   20   12000          4

# %%
# Three of columns are numerical columns, for which we can calculate the z-score.
# We can use the scipy.stats.zscore() function to calculate the z-scores on a Pandas dataframe column. 
# Let’s create a new column that contains the values from the Income column normalized using the z-score:

df['Income zscore'] = stats.zscore(df['Income'])  # we've assigned a new item to the dict
print(df.head())
# Out:
#     Name  Age  Income  Education  Income zscore
# 0    Nik   32   80000          5       0.978700
# 1   Kate   30   90000          7       1.304934
# 2    Joe   67   45000          3      -0.163117
# 3  Mitch   34   23000          4      -0.880830
# 4  Alana   20   12000          4      -1.239687

# %% [markdown]
# One of the benefits of calculating z-scores is to actually normalize values across features. Because of this, it’s often useful to calculate the z-scores for all numerical columns in a dataframe.
#
# Let’s see how we can convert our dataframe columns to z-scores using the Pandas .apply() method:

# %%
df = df.select_dtypes(include='number').apply(stats.zscore)
print(df.head())
# Out:
#         Age    Income  Education  Income zscore
# 0 -0.288493  0.978700   0.294884       0.978700
# 1 -0.413925  1.304934   1.769303       1.304934
# 2  1.906565 -0.163117  -1.179536      -0.163117
# 3 -0.163061 -0.880830  -0.442326      -0.880830
# 4 -1.041085 -1.239687  -0.442326      -1.239687

# %% [markdown]
# In the example above, we first select only numeric columns using the .select_dtypes() method and then use the .apply() method to apply the zscore function.
#
# The benefit of this, is that we’re now able to compare the features in relation to one another in a way that isn’t impacted by their distributions.

# %% [markdown]
# # Scatter Plot

# %%
# import related lbraries
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# mpg dataset (mpg: miles per gallone)

df = sns.load_dataset("mpg")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# boyutunu gormek icin
len(df)
# Out:
# 398

# %%
# aradan 10 tane farklı getirmek istiyoruz diyelim. dataframe objectin sample() methodunu kullanırız
df.sample(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 5    15.0          8         429.0       198.0    4341          10.0
# 222  17.0          8         260.0       110.0    4060          19.0
# 391  36.0          4         135.0        84.0    2370          13.0
# 110  22.0          4         108.0        94.0    2379          16.5
# 141  29.0          4          98.0        83.0    2219          16.5
# 158  16.0          8         318.0       150.0    4498          14.5
# 397  31.0          4         119.0        82.0    2720          19.4
# 13   14.0          8         455.0       225.0    3086          10.0
# 15   22.0          6         198.0        95.0    2833          15.5
# 197  29.0          4          90.0        70.0    1937          14.2
#
#      model_year  origin                        name
# 5            70     usa            ford galaxie 500
# 222          77     usa  oldsmobile cutlass supreme
# ...

# %%
# mpg ve horsepower degiskenleri arasındaki ilişkyi araştıralım
# draw a scatter plot between mpg and horsepower
sns.scatterplot(x = "mpg", y = "horsepower", data = df)  
# parantez icinde shft+tab yap. scatterplot(x ekseni, y ekseni)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='horsepower'>

# %%
# acceleration ve weight arasındaki ilişkiye bakalım

sns.scatterplot(x = "weight", y = "acceleration", data = df)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='acceleration'>

# %%
sns.scatterplot(x = "acceleration", y = "horsepower", data = df)
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='horsepower'>

# %%
sns.pairplot(df)
# tüm ilişkileri cizdirir.
# sadece sayısal değişkenler için (7 tane) 7ye 7 bir matris cizdirdi

# %% [markdown]
# # correlation

# %%
#Define two variables as x and y
x = [93, 84, 82, 78, 98, 70]
y = [13, 10, 11, 8, 15, 9]

# %%
# check the covariance between x and y
np.cov(x,y)
# 24ler covaryans, 6.8 yenin varyans, 102 xin
# Out:
# array([[102.56666667,  24.        ],
#        [ 24.        ,   6.8       ]])

# %%
np.std(x)
# Out:
# 9.24511883223911

# %%
np.var(x)
# Out:
# 85.47222222222223

# %%
np.var(y, ddof=1)
# Out:
# 6.8

# %%
np.var(x, ddof=1)
# Out:
# 102.56666666666668

# %%
# check the correlation between x and y
np.corrcoef(x,y)
# aynı mantık. 1ler x-x, y-y korelasyonu. 0,9.. korelayon. + ve strong
# Out:
# array([[1.        , 0.90876934],
#        [0.90876934, 1.        ]])

# %%
np.corrcoef(x,y)[0][1]
# Out:
# 0.9087693361896165

# %%
# ama hesaplamalarda daha çok pandas corr kullanılır.
# pandas correlation
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.corr()
# default pearson. degistirmek istersen örn (method = "spearman") veya (method = "kendall")
# tamamının birbirine korelasyonlarını verir
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
# mpg-horsepower arası -0.77
# weight-accel arası-0.41

# %%
# peki ayrı ayrı korelayonları nasıl getiririz
df["cylinders"].corr(df["displacement"])
# Out:
# 0.9507213901392411

# %%
# df.corr() tablosu kullanisli ama veri cok büyüyünce zoelasiyor anlamasi. bunun icin heatmap var
# draw a heatmap of corrrelation matrix
sns.heatmap(df.corr(), annot=True)
# annot=True kor.katsayıları icine yazdırmak icin
# Out:
# <AxesSubplot:>

# %%
# bununla toplam meanleri vs de gorebiliriz
df.describe()
# hepsinin istatistiklerini gösterir.
# aşağıdaki tabloda horsepower 392; yani 6 verisi eksik.
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# # scipy stats library ile correlation

# %%
stats.pearsonr(df["cylinders"], df["displacement"])  # parametric correlation
# Out:
# (0.9507213901392411, 1.696994710899583e-203)

# %%
stats.pearsonr(df["cylinders"], df["displacement"])[0]
# Out:
# 0.9507213901392411

# %%
stats.spearmanr(df["cylinders"], df["displacement"])  # nonparametric correlation
# Out:
# SpearmanrResult(correlation=0.9118759147045389, pvalue=3.1653222842819385e-155)

# %% [markdown]
# # Another example

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
df["total_bill"].corr(df["tip"])
# Out:
# 0.6757341092113641

# %%
sns.boxplot(df["total_bill"], df["tip"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.pairplot(df)
