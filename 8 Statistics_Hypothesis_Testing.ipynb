# %% [markdown]
# # Hypothesis Testing
#
# Significance test
#
# # Statistical Hypotheses
#
# In statistics, a hypothesis is a statement about a population, usually claiming that a parameter takes a particular numerical value or falls in a certain range of values.
#
# Unlike the other hypothesis testing of science, statistical hypothesis testing always involves assessing an assertion made about the value of a population parameter. This assertion is stated as a pair of statements: **the null hypothesis (Ho) and the alternative hypothesis (Ha or H1).**
#
# **The null hypothesis always expresses equality and it is the thing we are trying to provide evidence against. However, the alternative hypothesis is usually the idea we are studying about and typically it is the thing that we want to prove.**
#
# Before conducting a hypothesis testing, we identify the variable measured and the population parameter of interest. For a categorical variable the parameter is a proportion, and for a quantitative variable the parameter is a mean.

# %% [markdown]
# # The Steps of a Hypothesis Testing
#
# A significance test has five steps. In this section, we introduce the general ideas behind these steps.
#
# 1. assumptions ve given variablesı yaz (h0, h1- xbar,sem, n, sigma vs)
# 2. test statistic: z veya t testi
# 3. p_value
# 4. alpha ile p_value karsilastirip sonuc
#
# **1. Assumptions**
#
# First, specify the variable and parameter. The assumptions commonly pertain to the method of data production (randomization), the sample size, and the shape of the population distribution.
#
# z testi icin:
#
# ![image.png](attachment:01409165-85a1-47c0-9efa-0bc019d68fd0.png)
#
# t testi icin :
#
# ![image.png](attachment:af6c57de-92fe-406e-9f57-ef1b65ede11f.png)
#
#
# **2. Hypotheses**
#
# State the null hypothesis, H0 (a single parameter value, usually no effect), and the alternative hypothesis, Ha (a set of alternative parameter values)
#
# Example-1
#
# Null Hypotheses : The population mean time to answer customer complaints was 5 minutes in 2020.
#
# Alternative Hypotheses : The population mean time to answer customer complaints was not 5 minutes in 2020.
#
# Example-2
#
# Null Hypotheses : The average weight for men is the same as the average weight for women in USA.
#
# Alternative Hypotheses : The average weight for men is not the same as the average weight for women in USA.
#
# - 1 write down the given variables
# - n = 40
# - sigma = 1.5
# - alpha = 0.05
# - xbar = 10.5
# - µ = 10
#
# **3. Test Statistic**
#
# The parameter to which the hypotheses refer has a point estimate. **A test statistic describes how far that point estimate falls from the parameter value given in the null hypothesis.** Usually this distance is measured by the number of standard errors between the point estimate and the parameter.
#
# one sample veya two sample olmasınna ve std bilinip bilinmemesine gore z veya t scoreu bul
#
# Eger one sample z testi ise;
#
# - z = (xbar-µ)/(sigma/np.sqrt(n))  (bu test statistic oluyor)
# - z
#
# Eger one sample t testi ise o zaman std(sigma) yerine standart hata (s - meanin std'si (sigma for pop std)) kullanırız:
#
# - t = (xbar-µ) / (s / np.sqrt(n))
# - t
#
# **4. P-value**
#
# The P-value is the probability that the test statistic takes the observed value or a value more extreme if we presume H0 is true. **Smaller P-values represent stronger evidence against H0.**
#
# **P value bir olasılıktır, her zaman 0-1 arasındadır. P-value bir sartli olasılıktır, H0'ın true olması conditionunda birseyin olma olasiligi, bir olayın olma olasılığıdır.**
#
# P-value, sıfır hipotezi doğru olduğunda (şartlı olasılık), gözlemlenen (xbar) veya daha uçtaki (extreme) sonuçları bulma olasılığıdır.
#
# P(t > t0 | H0 true)
#
# Ornegin suyu kursunlu mu diye olcum yapılacak bir kumsaldan 40 su sample alınıyor. Lead meanin 10 oldugu iddia ediliyor. sample mean ise 10.5. pop std 1,5. yani sample s'si 1.5/ np.sqrt(40), yani 0,23. 3. rule da bu bir normal dist. Bu bir normal dist ise 1 std saga gidersek 10.24 olur, bir de sola 9.76. bu 68% dir. saga sola 2ser stg gidersek 9.52 ve 10.48 olur. yani alınacak su sampleının meaninin 10.48'den fazla cikma olasılığı100 - 95(%). ama 2 taraf oldugu icin 2.5(tam olarak 2.3). yani 10.5 cikma olasılğı 2.3% civarında (biraz daha kucuk). iste bu p_value'dur. H0 dogru olması durumunda xbar'ın 10.5 cikma ihtimali p_value'dur, yani 0.023tür. p_value kücük oldukca, significance test, yani hypothesis test, o kadar güclü olur. burada h0 reject edilir, lead mean 10 olmadigi icin plaj kapatılır. peki gercekte kursun oranı kacmis sorusunun cevabını ise confidence interval verir. %95 guven araliginda 10.5 etrafında artı eksi 0.465'tir. Sampledan anakütle hakkinda yorum yaparken ci kullanırız.
#
# One sample z test icin:
#
# - Eğer tek taraflı ve right tail ise, yani xbar > µ ise p_value = 1 - stats.norm.cdf(z), cunku alan hesaplama soldan baslar;
# - Eğer tek taraflı ve left tail ise, yani xbar < µ ise p_value = stats.norm.cdf(z)
#
# One sample t test icin degrees of freedom = n-1 de kullanırız:
#
# - Eger h1 < h0 ise left tail olacak (1 - olmaz yani): p_value = stats.t.cdf(t, df = n-1)
# - Eger h1 > h0 ise right tail olacak (1 - olur) p_value = 1 - stats.t.cdf(t, df = n-1)
#
#
# ![image.png](attachment:d818ab9a-7e16-471d-a988-69431bde0a39.png)
#
# **5. Conclusion**
#
# Report and interpret the P-value in the context of the study. Based on the P-value, make a decision about H0 (either reject or do not reject H0 ) if a decision is needed.
#
# - 4. conlusion: p value ve alpha karsilastirmasi ve sonuc
#
# - if p_value < alpha:
# -    print('At {} level of significance, we reject the null hypothesis in favor of alternative hypothesis.'.format(alpha))
# - else:
# -    print('At {} level of significance, we fail to reject the null hypothesis.'.format(alpha))
#
# Nutshell:
#
#
# 1. z değerini bul.
#
# 2. o z değerine karşılık gelen p value'yu bul.
#
# 3. p value'yu kritik value ile kıyasla

# %% [markdown]
# # One and Two Tailed Tests
#
# **Two-tailed**: Sometimes the Rejection Region is broken into two parts and lies in both tails of the sampling distribution of the test statistic (when H0:μ = μ0 is true)
#
# H0: "Drug has no effect (μ = μ0)"
#
# H1: "Drug has an effect (μ ≠ μ0)"
#
# **One-tailed**: Sometimes the Rejection Region lies entirely in one tail of the sampling distribution of the test statistic (when H0:μ = μ0 is true versus H1:μ > μ0).
#
# H0: "Drug has no effect (μ = μ0)"
#
# H1: "Drug lowers response time (μ < μ0)"
#
# ![image.png](attachment:b44e9319-9175-4a52-a401-66ca4b425b0d.png)

# %% [markdown]
# # Significance Level and P-Value
#
# # Significance Level
#
# **The significance level (alpha or α)**, is a measure of the strength of the evidence to be present in the sample before you will reject the null hypothesis and conclude that the effect is statistically significant. Before conducting the experiment, the researcher determines the significance level. And we can say the typical values for the significance level are 0.1, 0.05, and 0.01.
#
# In other words, **the significance level is the probability of rejecting the null hypothesis when it is true.** For instance, a significance level of 0.05 represents a 5% risk of concluding that a difference exists when there is no actual difference. A lower significance level indicates that we require stronger evidence before rejecting the null hypothesis.
#
# # P-Value
#
# A p-value is the probability that we would obtain the effect observed in our sample, if the null hypothesis is true for the population. P-value is calculated based on our sample data and under the assumption that the null hypothesis is true. **A lower p-value indicates greater evidence against the null hypothesis**.
#
# Using the significance level and p-value during hypothesis testing helps us determine which hypothesis the data support. We compare the p-value with the significance level. **If the p-value is less than our significance level, we can reject the null hypothesis and conclude that the effect is statistically significant.** In other words, the evidence in our sample is strong enough to be able to reject the null hypothesis at the population level.
#
# One sample z test icin:
#
# - Eğer tek taraflı ve right tail ise, yani xbar > µ ise p_value = 1 - stats.norm.cdf(z), cunku alan hesaplama soldan baslar;
# - Eğer tek taraflı ve left tail ise, yani xbar < µ ise p_value = stats.norm.cdf(z)
#
# One sample t test icin degrees of freedom = n-1 de kullanırız:
#
# - Eger h1 < h0 ise left tail olacak (1 - olmaz yani): p_value = stats.t.cdf(t, df = n-1)
# - Eger h1 > h0 ise right tail olacak (1 - olur) p_value = 1 - stats.t.cdf(t, df = n-1)
#
#
# - ciift taraflıysa 2 ile carpiyoruz
# ![image.png](attachment:69701599-f0e8-49f2-b198-bada2a806de8.png)

# %% [markdown]
# # Type-I and Type-II Errors
#
# A hypothesis test is not 100% reliable because it uses a random sample to draw a conclusion about the entire population. When we perform a hypothesis test, there are two types of errors related to drawing an incorrect conclusion.
#
# **Type I error**: That rejects a null hypothesis although it is true. We can think of this as a **false positive**.
#
# **Type II error**: That test fails to reject a null hypothesis although it is false. We can think of this as a **false negative**.
#
# ![image.png](attachment:cea402f8-3979-4419-a988-2279a6e053d6.png)

# %% [markdown]
# ![image.png](attachment:2d209846-3056-4858-83c6-6d8810e00ba6.png)

# %% [markdown]
# # one sample z test
#
# - performed when the population variance or standard deviation is known
#
# - populasyon std'si (sigma) biliniyorsa veya 30 observation size varsa kullanılabilir. bunlardan birisi yoksa t.

# %%
import numpy as np
from scipy import stats
import pandas as pd

# %% [markdown]
# ![image.png](attachment:65bb4e5a-6d8a-4806-a067-440454f49933.png)

# %%
# H0 : µ = 10
# H1 : µ > 10

# 1 MANUAL method

# 1. first write the given variables
µ = 10
xbar = 10.5
n = 40
sigma = 1.5  # std of popuation
alpha = 0.05

# %%
# 2. calculate the test statistic

z = (xbar-µ)/(sigma/np.sqrt(n)) 
z
# Out:
# 2.1081851067789197

# %%
# 3. afterthat, calculate the p-value

# alternative h > olduğu icin tek kuyruk, sag tarafta.. alan hesaplaması soldan baslar bu nedenle 1 - stats.norm.cdf(z)
# z testi nedeniyle normal dagilim kullaniyoruz bu nedenle norm, t degil
stats.norm.cdf(z)
# Out:
# 0.9824925094901688

# %%
# bu tum alan, kuyrukta kalan alan da 1 - yukarıdakidir

p_value = 1 - stats.norm.cdf(z)
p_value
# Out:
# 0.017507490509831247

# %%
# 4. conlusion: p value ve alpha karsilastirmasi ve sonuc

if p_value < alpha:
    print('At {} level of significance, we reject the null hypothesis in favor of alternative hypothesis.'.format(alpha))
else:
    print('At {} level of significance, we fail to reject the null hypothesis.'.format(alpha))
# Out:
# At 0.05 level of significance, we reject the null hypothesis in favor of alternative hypothesis.

# %%
# WITH PYTHON
# H0 : µ = 10
# H1 : µ > 10

import numpy as np
np.random.seed(42)
x = np.random.normal(loc= 10.5, scale= 1.5/np.sqrt(40), size=40)
x
# Out:
# array([10.61780611, 10.46720774, 10.65361282, 10.86121825, 10.44446565,
#        10.44446954, 10.87454321, 10.68201313, 10.38865437, 10.62867941,
#        10.39009084, 10.38954249, 10.55738639, 10.04622575, 10.09089982,
#        10.3666418 , 10.25978601, 10.5745303 , 10.28464318, 10.16504277,
#        10.84760913, 10.44645245, 10.51601572, 10.1620913 , 10.3708883 ,
#        10.5263076 , 10.2270179 , 10.58910461, 10.35754603, 10.43081875,
#        10.35729275, 10.93930634, 10.49679885, 10.24914183, 10.69508366,
#        10.2104515 , 10.54953635, 10.03522342, 10.18499302, 10.54668974])

# %%
onesample = stats.ttest_1samp(x, 10, alternative="greater")
onesample
# Out:
# TtestResult(statistic=12.542443226991564, pvalue=1.4499569620327462e-15, df=39)

# %% [markdown]
# # Example 2
#
# ![image.png](attachment:ea7e7e84-9545-4677-888a-69494f7a4c0a.png)

# %%
# H0 : µ0 = 170
# H1 : µ > 170
# 1 wrtite the variables
xbar = 178
n = 400
sigma = 65
# std yerine var verirse onu stdye ceviririz
µ = 170
alpha = 0.05
# alpha verilmemisse 0.05 aliriz.

# %%
# 2 z 
z = (xbar-µ)/(sigma/np.sqrt(n))                        # test statistic 
z
# Out:
# 2.4615384615384617

# %%
# ek bilgi: bu arada standard error yukardaki formulun ikinic kismi
(sigma/np.sqrt(n)

# %%
# 3 p value
p_value = 1 - stats.norm.cdf(z)  # cdf soldan itibaren alan hesaplar. bu nedenle left ise 1den cikarmayız,
# ama burada right tail oldugu icin 1den cikaririz.
p_value
# Out:
# 0.006917128192854505

# %%
# 4 result

if p_value < alpha:
    print('At {} level of significance, we reject the null hypothesis in favor of alternative hypothesis.'.format(alpha))
else:
    print('At {} level of significance, we fail to reject the null hypothesis.'.format(alpha))
    
# so it is cost effective to install the new billing system.
# Out:
# At 0.01 level of significance, we reject the null hypothesis in favor of alternative hypothesis.

# %%
# tek satırda p_value nasıl hesaplanır
# standart hata 3.25 ve xbar ve mean ile yaparız
1 - stats.norm.cdf(178, 170, 3.25)

# %% [markdown]
# # BAska bir ornek
#
# The hourly wages in a particular industry are normally distributed with mean 13.20 Dollars and standard deviation 2.50 Dollars. A company in this industry employs 40 workers, paying them an average of $12.20 per hour. Can this company be accused of paying substandard wages? Use an α = .01 level test. (Wackerly, Ex.10.18)
#
# CHECK: statistic: -2.5298221281347035, pvalue= 0.005706018193000826

# %%
# 1. first write the given variables

# H0: µ = 13.20
# H1: µ < 13.20
# 1. the variables
xbar = 12.20
n = 40
sigma = 2.50
µ = 13.20
alpha = 0.01

# %%
# 2. calculate the test statistic

z = (xbar-µ)/(sigma/np.sqrt(n))
z
# Out:
# -2.5298221281347035

# %%
# 3. calculate the p-value

# left tailed - alternative h < ... bu nedenle 1den cikarmayız. 

p_value = stats.norm.cdf(-2.5298221281347035) 
p_value
# Out:
# 0.005706018193000826

# %%
# 4. conlusion

if p_value < alpha:
    print('At {} level of significance, we reject the null hypothesis in favor of alternative hypothesis.'.format(alpha))
else:
    print('At {} level of significance, we fail to reject the null hypothesis.'.format(alpha))
# Out:
# At 0.01 level of significance, we reject the null hypothesis in favor of alternative hypothesis.

# %% [markdown]
# ![image.png](attachment:d2ca44b9-9fbd-451a-9545-759f8ac14430.png)

# %% [markdown]
# # One Sample T-test
#
# population std bilinmiyorsa t-testi kullanılır
#
# # Example 1
#
# ![image.png](attachment:0a46be17-e52c-4cff-a7f9-dcabc0fe0f4d.png)

# %%
# H0: µ = 110
# H1: µ < 110
# 1. the variables
xbar = 108
n = 20
s = 10  # sample std si
µ = 110
alpha = 0.01

# %%
# calculate t. pop std is unknown, we just know the standard error s
t = (xbar-µ) / (s / np.sqrt(n))
t
# Out:
# -0.8944271909999159

# %%
# 3 caculate p value
# t dagilimi icin df degrees of freedom lazim
# kücüktür oldugu icin left-tailed hypotesis test

p_value = stats.t.cdf(t, df = n-1) 
p_value
# Out:
# 0.1911420676837155

# %%
if p_value < alpha:
    print('At {} level of significance, we reject the null hypothesis in favor of alternative hypothesis.'.format(alpha))
else:
    print('At {} level of significance, we fail to reject the null hypothesis.'.format(alpha))
    
    
# the principal should accept her original hypothesis.
# Out:
# At 0.01 level of significance, we fail to reject the null hypothesis.

# %%
# mesela p value biliyor olsaydık geri gidip t'yi de bulabiliriz

stats.t.ppf(p_value, df=n-1)
# Out:
# -0.8944271909999159

# %%
# critical value'yu da bulabiliriz yine

stats.t.ppf(alpha, df=n-1)
# eger -2.53ten kücük olsaydı reddedebilirdik

# yani ya pi value ile alphayı, ya da
# Out:
# -2.5394831906222888

# %% [markdown]
# # WE CAN USE PYTHON STATS INSTEAD OF THIS TRADITIONAL CALCULATION

# %%
# EXAMPLE 1

# suppose we hypothesize that the population mean of bmi among Pima Indian women is equal to 30.
# However we found sample mean as x_bar = 32.3

# bmi mean:
# Ho: mu = 30
# Ha: mu > 30


import statsmodels.api as sm

df = sm.datasets.get_rdataset(dataname = "Pima.tr", package = "MASS")
df.keys()
# Out:
# dict_keys(['data', '__doc__', 'package', 'title', 'from_cache'])

# %%
df.data
# Out:
#      npreg  glu  bp  skin   bmi    ped  age type
# 0        5   86  68    28  30.2  0.364   24   No
# 1        7  195  70    33  25.1  0.163   55  Yes
# 2        5   77  82    41  35.8  0.156   35   No
# 3        0  165  76    43  47.9  0.259   26   No
# 4        0  107  60    25  26.4  0.133   23   No
# ..     ...  ...  ..   ...   ...    ...  ...  ...
# 195      2  141  58    34  25.4  0.699   24   No
# 196      7  129  68    49  38.5  0.439   43  Yes
# 197      0  106  70    37  39.4  0.605   22   No
# 198      1  118  58    36  33.3  0.261   23   No
# 199      8  155  62    26  34.0  0.543   46  Yes
#
# [200 rows x 8 columns]

# %%
df = df.data

# %%
df.head()
# Out:
#    npreg  glu  bp  skin   bmi    ped  age type
# 0      5   86  68    28  30.2  0.364   24   No
# 1      7  195  70    33  25.1  0.163   55  Yes
# 2      5   77  82    41  35.8  0.156   35   No
# 3      0  165  76    43  47.9  0.259   26   No
# 4      0  107  60    25  26.4  0.133   23   No

# %%
df.info()
# 200 is n , sample size
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   npreg   200 non-null    int64
#  1   glu     200 non-null    int64
#  2   bp      200 non-null    int64
#  3   skin    200 non-null    int64
#  4   bmi     200 non-null    float64
#  5   ped     200 non-null    float64
#  6   age     200 non-null    int64
#  7   type    200 non-null    object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 12.6+ KB

# %%
df.describe()
# bmi'nin ilk 3 satiri onemli bizim icin, count (n), mean ve std
# Out:
#             npreg         glu          bp        skin         bmi         ped  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     3.570000  123.970000   71.260000   29.215000   32.310000    0.460765
# std      3.366268   31.667225   11.479604   11.724594    6.130212    0.307225
# min      0.000000   56.000000   38.000000    7.000000   18.200000    0.085000
# 25%      1.000000  100.000000   64.000000   20.750000   27.575000    0.253500
# 50%      2.000000  120.500000   70.000000   29.000000   32.800000    0.372500
# 75%      6.000000  144.000000   78.000000   36.000000   36.500000    0.616000
# max     14.000000  199.000000  110.000000   99.000000   47.900000    2.288000
#
#               age
# count  200.000000
# mean    32.110000
# std     10.975436
# min     21.000000
# 25%     23.000000
# 50%     28.000000
# 75%     39.250000
# max     63.000000

# %%
df.bmi.mean()
# Out:
# 32.30999999999998

# %%
# sample size = 200
# sample std = 6.13
# sample mean = 32.3

# %%
import scipy.stats as stats
onesample = stats.ttest_1samp (df["bmi"], 30)
onesample
# Out:
# TtestResult(statistic=5.329070841262502, pvalue=2.6614410307455736e-07, df=199)

# %%
onesample.pvalue/2
# 2 ye bolduk cunku bu tek tarafli (greater) olmasına karsin biz alternative parametresini yazmadık ve default
# two-sided aldi. bu nednele burada 2 ye bolduk. ama onun yerine asagidaki gibi de yapabiliriz 


# sondaki -7 demek .'dan once 6 sıfır ve sonra 2 geliyor. yani cok dusuk pvalue
# Out:
# 1.3307205153727868e-07

# %%
onesample = stats.ttest_1samp (df["bmi"], 30, alternative="greater")
onesample
# Out:
# TtestResult(statistic=5.329070841262502, pvalue=1.3307205153727868e-07, df=199)

# %%
alpha = 0.05
if onesample.pvalue/2<alpha:
    print('At {} level of significance, we can reject the null hypothesis in favor of alternative hypothesis.'.format(alpha))
else:
    print('At {} level of significance, we fail to reject the null hypothesis.'.format(alpha))
# Out:
# At 0.05 level of significance, we can reject the null hypothesis in favor of alternative hypothesis.

# %% [markdown]
# (Önceden ortalaması bilinen bir dağılım ile elimizdeki örneklemi karşılaştırmak için kullanılır. Aynı zamanda elde edilen örneklemin var sayılan bir dağılımdan fark gösterip göstermediğini test etmek için de uygulanabilir.)
#
# **Example 2**
#
# - According to Reynolds Intellectual Ability Scales, the average VIQ (Verbal IQ scores based on the four Wechsler (1981) subtests) is about 109.
#
# - In our sample data, we have a sample of 40 cases. (tek samplela calisiyoruz ama sample size 40. 40 sample degil yani)
# - Let's test if the average VIQ of people is significantly bigger than 109.

# %%
# Brain size and weight and IQ data (Willerman et al. 1991)
df = pd.read_csv("brain_size.csv", sep=";", na_values = ".", index_col = 0)

# %%
df.shape
# Out:
# (40, 7)

# %%
df.head()
# Out:
#    Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 1  Female   133  132  124   118.0    64.5     816932
# 2    Male   140  150  124     NaN    72.5    1001121
# 3    Male   139  123  150   143.0    73.3    1038437
# 4    Male   133  129  128   172.0    68.8     965353
# 5  Female   137  132  134   147.0    65.0     951545

# %%
# H0: mu = 109
# H1: mu > 109

# %%
# 21. ASIL KULLANACAGIMIZ YONTEM

# Use stats.ttest_1samp() to calculate the test statistic and p-value
oneSamp = stats.ttest_1samp(df.VIQ, 109, alternative='greater')
# tek taraf ise alternative greater deriz.
# arastrcagimiz sutunu koyup onu karsilastiracagimiz meani yaziyor ve sonra da tek taraf iki taraf olmasına gore 
# alternative seciyoruz.
oneSamp
# Out:
# TtestResult(statistic=0.8971529586323551, pvalue=0.18757115929257173, df=39)

# %%
#Display p-value
oneSamp.pvalue
# Out:
# 0.18757115929257173

# %%
# Compare p-value and alpha
alpha = 0.05

if oneSamp.pvalue < alpha:
    print("Reject the null")
else:
    print("Fail to reject the null")
# Out:
# Fail to reject the null

# %%
# 2. TRADITIONAL SOLUTION

# Calculate the mean of VIQ
xbar = df.VIQ.mean()
xbar
# µ 109, bu ise samplemızın avg.ı
# Out:
# 112.35

# %%
# 1. manuel yontem
# Calculate the std of VIQ
s = df.VIQ.std()
s
# Out:
# 23.616107063199735

# %%
s/np.sqrt(df.shape[0])
# Out:
# 3.7340343893050596

# %%
# Calculate the test statistic
t_test = (xbar - 109)/(s/np.sqrt(df.shape[0]))

# %%
#test statistic
t_test
# Out:
# 0.8971529586323553

# %%
# Calculate p-value
1 - stats.t.cdf(t_test, 39)
# Out:
# 0.18757115929257173
